# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = "LL-Output-Tue-12-Mar-2024-at-05-21-16PM.txt"
df = pd.read_csv(data, sep='\s+', skiprows=7)
df = df.drop(columns=['Energy:', 'Order:'])
df = df.rename(columns={'Ratio:' : 'Order', 'step:' : 'Energy', 'MC' : 'Ratio',  '#' : 'MC_step' })
df = df.drop(df.index[0])
df.iloc[1:, 0] = df.iloc[1:, 0].astype(str).str.lstrip('0')

df
# Out:
#    MC_step   Ratio    Energy   Order
# 1    00000  0.5000  -64.5381  0.2537
# 2        1  0.5044  -90.3747  0.2577
# 3        2  0.4224 -102.2555  0.2562
# 4        3  0.8820  -98.6593  0.2753
# 5        4  0.6696 -103.6798  0.2834
# 6        5  0.4168 -116.1638  0.2990
# 7        6  0.5080 -124.8833  0.3032
# 8        7  0.4528 -131.8547  0.3036
# 9        8  0.5800 -128.4688  0.3036
# 10       9  0.2704 -139.7970  0.3086
# 11      10  0.8736  -99.6749  0.2984
# 12      11  0.4636 -110.4812  0.2913
# 13      12  0.7716 -109.2156  0.2931
# 14      13  0.5596 -121.0059  0.3048
# 15      14  0.4796 -132.9945  0.3070
# 16      15  0.2908 -146.9153  0.3140
# 17      16  0.5308 -144.4081  0.3173
# 18      17  0.4952 -146.3546  0.3229
# 19      18  0.4688 -150.6133  0.3261
# 20      19  0.2548 -158.1517  0.3367
# 21      20  0.3316 -161.6224  0.3357
# 22      21  0.4144 -163.1267  0.3470
# 23      22  0.5128 -158.7977  0.3513
# 24      23  0.5532 -154.9684  0.3511
# 25      24  0.4420 -159.5595  0.3486
# 26      25  0.4496 -159.1556  0.3540
# 27      26  0.4128 -165.4160  0.3597
# 28      27  0.7592 -141.9275  0.3521
# 29      28  0.4160 -152.2572  0.3543
# 30      29  0.4064 -153.5952  0.3577
# 31      30  0.7952 -118.7499  0.3435
# 32      31  0.6636 -127.0103  0.3488
# 33      32  0.3316 -143.3208  0.3495
# 34      33  0.6556 -136.3111  0.3468
# 35      34  0.3992 -144.0143  0.3513
# 36      35  0.4776 -146.0482  0.3583
# 37      36  0.5784 -141.4319  0.3685
# 38      37  0.2780 -147.8603  0.3684
# 39      38  0.3648 -154.5952  0.3636
# 40      39  0.4384 -152.1665  0.3708
# 41      40  0.3328 -154.6273  0.3719
# 42      41  0.3712 -161.1289  0.3696
# 43      42  0.6560 -140.6235  0.3660
# 44      43  0.5488 -143.7023  0.3565
# 45      44  0.4840 -147.0594  0.3548
# 46      45  0.2720 -159.6357  0.3531
# 47      46  0.4152 -160.1486  0.3503
# 48      47  0.3732 -164.0497  0.3571
# 49      48  0.6260 -157.0095  0.3512
# 50      49  0.4556 -157.5904  0.3524
# 51      50  0.5044 -156.6563  0.3517

# %%
# Plotting change in energy over each MCS
plt.figure(figsize=(10, 5))
plt.plot(df['MC_step'], df['Energy'], linestyle='-')
plt.xlabel('MC_step')
plt.ylabel('Reduced Energy')
plt.title('MC Step vs Reduced Energy')

plt.xticks(df['MC_step'][::10])

plt.show()

# %%
# Plotting MC_step v order Paramter S
plt.figure(figsize=(10, 5))
plt.plot(df['MC_step'], df['Order'], linestyle='-')
plt.xlabel('MC_step')
plt.ylabel('Order Parameter, S')
plt.title('MC Step v Order')


plt.xticks(df['MC_step'][::10])

plt.show()
