# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = "LL-Output-Tue-12-Mar-2024-at-09-20-23AM.txt"
df = pd.read_csv(data, sep='\s+', skiprows=7)
df = df.drop(columns=['Energy:', 'Order:'])
df = df.rename(columns={'Ratio:' : 'Order', 'step:' : 'Energy', 'MC' : 'Ratio',  '#' : 'MC_step' })
df = df.drop(df.index[0])
df.iloc[1:, 0] = df.iloc[1:, 0].astype(str).str.lstrip('0')

df
# Out:
#    MC_step   Ratio     Energy   Order
# 1    00000  0.5000 -2468.3651  0.2730
# 2        1  0.6748 -3761.8439  0.2946
# 3        2  0.6064 -4580.6560  0.2953
# 4        3  0.5680 -5048.2141  0.2956
# 5        4  0.5564 -5526.0957  0.2955
# 6        5  0.5092 -5813.5250  0.2797
# 7        6  0.4972 -6043.0010  0.2697
# 8        7  0.5052 -6277.0946  0.2701
# 9        8  0.4792 -6403.8803  0.2761
# 10       9  0.4600 -6566.4601  0.2784
# 11      10  0.4576 -6676.2098  0.2914
# 12      11  0.4632 -6744.5010  0.3036
# 13      12  0.4472 -6806.5015  0.3047
# 14      13  0.4416 -6899.9452  0.3005
# 15      14  0.4484 -6969.5951  0.3056
# 16      15  0.4532 -6999.0729  0.3036
# 17      16  0.4448 -6980.2757  0.2978
# 18      17  0.4700 -7037.0434  0.3040
# 19      18  0.4300 -7075.1602  0.3044
# 20      19  0.4436 -7099.0600  0.3029
# 21      20  0.4520 -7182.4553  0.3025
# 22      21  0.4228 -7295.4958  0.3080
# 23      22  0.4208 -7261.5765  0.3152
# 24      23  0.4356 -7326.8661  0.3168
# 25      24  0.4140 -7334.1122  0.3243
# 26      25  0.4424 -7379.5609  0.3296
# 27      26  0.4124 -7386.7320  0.3352
# 28      27  0.4180 -7367.5248  0.3386
# 29      28  0.4244 -7395.6726  0.3337
# 30      29  0.4284 -7420.8357  0.3341
# 31      30  0.4340 -7395.8038  0.3403
# 32      31  0.4472 -7503.5714  0.3474
# 33      32  0.4228 -7470.6396  0.3441
# 34      33  0.4136 -7455.8247  0.3450
# 35      34  0.4080 -7442.6689  0.3356
# 36      35  0.4456 -7440.3578  0.3483
# 37      36  0.4212 -7515.5861  0.3541
# 38      37  0.4204 -7506.9935  0.3592
# 39      38  0.4196 -7589.9919  0.3614
# 40      39  0.4180 -7612.0102  0.3556
# 41      40  0.4232 -7665.7980  0.3515
# 42      41  0.4160 -7632.1283  0.3566
# 43      42  0.4224 -7633.7621  0.3536
# 44      43  0.4256 -7633.9512  0.3573
# 45      44  0.4252 -7604.9806  0.3533
# 46      45  0.4256 -7658.8124  0.3513
# 47      46  0.4080 -7664.4868  0.3436
# 48      47  0.4164 -7660.8277  0.3386
# 49      48  0.4272 -7668.8586  0.3409
# 50      49  0.4060 -7613.6354  0.3480
# 51      50  0.4160 -7658.7970  0.3503

# %%
# Plotting change in energy over each MCS
plt.figure(figsize=(10, 5))
plt.plot(df['MC_step'], df['Energy'], linestyle='-')
plt.xlabel('MC_step')
plt.ylabel('Reduced Energy')
plt.title('MC Step vs Reduced Energy')

plt.xticks(df['MC_step'][::10])

plt.show()

# %%
# Plotting MC_step v order Paramter S
plt.figure(figsize=(10, 5))
plt.plot(df['MC_step'], df['Order'], linestyle='-')
plt.xlabel('MC_step')
plt.ylabel('Order Parameter, S')
plt.title('MC Step v Order')


plt.xticks(df['MC_step'][::10])

plt.show()
