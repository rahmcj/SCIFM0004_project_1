# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = "LL-Output-Tue-12-Mar-2024-at-08-35-51PM.txt"
df = pd.read_csv(data, sep='\s+', skiprows=7)
df = df.drop(columns=['Energy:', 'Order:'])
df = df.rename(columns={'Ratio:' : 'Order', 'step:' : 'Energy', 'MC' : 'Ratio',  '#' : 'MC_step' })
df = df.drop(df.index[0])
df.iloc[1:, 0] = df.iloc[1:, 0].astype(str).str.lstrip('0')

df
# Out:
#    MC_step   Ratio    Energy   Order
# 1    00000  0.5000  -48.5616  0.2794
# 2        1  0.7700  -72.7049  0.2847
# 3        2  0.9144  -67.4298  0.2769
# 4        3  0.5272  -82.6489  0.2680
# 5        4  0.4980  -87.9314  0.2710
# 6        5  0.6196  -96.9477  0.2741
# 7        6  0.6540  -99.7847  0.2747
# 8        7  0.3912 -115.7895  0.2768
# 9        8  0.4636 -127.7743  0.2724
# 10       9  0.2992 -134.3145  0.2663
# 11      10  0.5380 -136.6935  0.2607
# 12      11  0.2788 -143.2559  0.2613
# 13      12  0.3284 -148.4634  0.2636
# 14      13  0.3144 -154.3504  0.2628
# 15      14  0.5824 -150.8494  0.2729
# 16      15  0.3672 -156.9556  0.2743
# 17      16  0.2368 -160.9838  0.2800
# 18      17  0.3692 -162.3415  0.2815
# 19      18  0.1916 -165.1498  0.2820
# 20      19  0.3168 -167.6052  0.2810
# 21      20  0.3212 -171.6510  0.2811
# 22      21  0.2880 -172.8053  0.2805
# 23      22  0.3120 -173.3579  0.2833
# 24      23  0.1904 -174.5146  0.2826
# 25      24  0.4660 -167.9797  0.2810
# 26      25  0.5576 -156.1061  0.2758
# 27      26  0.5224 -155.6935  0.2763
# 28      27  0.4672 -152.4071  0.2746
# 29      28  0.7084 -147.2118  0.2791
# 30      29  0.3792 -156.7143  0.2846
# 31      30  0.2516 -164.8934  0.2889
# 32      31  0.5776 -164.4089  0.2810
# 33      32  0.5208 -159.6541  0.2827
# 34      33  0.3744 -165.4549  0.2861
# 35      34  0.2368 -170.4690  0.2873
# 36      35  0.4048 -172.8933  0.2862
# 37      36  0.5668 -159.0818  0.2787
# 38      37  0.7168 -151.7698  0.2764
# 39      38  0.6284 -144.1088  0.2907
# 40      39  0.7084 -132.5221  0.2825
# 41      40  0.3556 -139.9616  0.2846
# 42      41  0.4528 -144.6513  0.2867
# 43      42  0.4760 -150.3492  0.2935
# 44      43  0.5392 -151.7056  0.2954
# 45      44  0.6504 -138.0914  0.2962
# 46      45  0.3384 -149.3361  0.2986
# 47      46  0.3916 -158.1979  0.2975
# 48      47  0.6012 -155.2518  0.2873
# 49      48  0.5452 -155.6733  0.2829
# 50      49  0.2984 -165.2092  0.2857
# 51      50  0.2676 -168.5760  0.2936

# %%
# Plotting change in energy over each MCS
plt.figure(figsize=(10, 5))
plt.plot(df['MC_step'], df['Energy'], linestyle='-')
plt.xlabel('MC_step')
plt.ylabel('Reduced Energy')
plt.title('MC Step vs Reduced Energy')

plt.xticks(df['MC_step'][::10])

plt.show()

# %%
# Plotting MC_step v order Paramter S
plt.figure(figsize=(10, 5))
plt.plot(df['MC_step'], df['Order'], linestyle='-')
plt.xlabel('MC_step')
plt.ylabel('Order Parameter, S')
plt.title('MC Step v Order')


plt.xticks(df['MC_step'][::10])

plt.show()
